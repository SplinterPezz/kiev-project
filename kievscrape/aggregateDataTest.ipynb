# %%
from pymongo import MongoClient
from datetime import datetime
from collections import defaultdict

mongo_db_name = "kiev"
mongo_collection_article_kiev = "articles"
mongo_collection_article_onu = "onuData"
mongo_url = "mongodb://"
number_of_tags = 10

# %%
from pymongo import MongoClient

def connect_mongo(mongo_url, mongo_db_name):
    client = MongoClient(mongo_url)
    mongo_db = client[mongo_db_name]
    return mongo_db

def get_collection(mongo_db, collection_name):
    return mongo_db[collection_name]

def get_all_from_collection(collection):
    return list(collection.find({}))

def append_tags(old_tags, new_tags):
    for new in new_tags:
        count = 1
        old_count = None
        found = False

        for old in old_tags:
            if old['title'] == new:
                old_count = old['count']
                count = old_count + 1
                found = True
                break

        if not found:
            old_tags.append({'title': new, 'count': count})
        else:
            old_tags.remove({'title': new, 'count': old_count})
            old_tags.append({'title': new, 'count': count})

    return old_tags

def clean_tags(tags, number_of_tags):
    sorted_tags = sorted(tags, key=lambda x: x['count'], reverse=True)
    return sorted_tags[:number_of_tags]

def normalize_date(dt):
    return dt.replace(hour=0, minute=0, second=0, microsecond=0)

def should_count_death(article):
    return bool(article.get('deaths')) or bool(article.get('deathsV2'))

def process_article_tags(existing_tags, article):
    tags = article.get('customTagSMV2')
    if tags:
        return append_tags(existing_tags, tags)
    return existing_tags

def get_article_kiev_aggregated(articles_kiev, number_of_tags):
    grouped_by_date = defaultdict(list)
    
    for article in articles_kiev:
        date = article.get('date')
        if date:
            normalized = normalize_date(date)
            grouped_by_date[normalized].append(article)

    aggregated_list = []

    for date, articles in grouped_by_date.items():
        aggregated = {
            'articlesCount': len(articles),
            'tags': [],
            'date': date,
            'deathCounts': 0
        }

        for article in articles:
            aggregated['tags'] = process_article_tags(aggregated['tags'], article)

            if should_count_death(article):
                aggregated['deathCounts'] += 1

        if aggregated['tags']:
            aggregated['tags'] = clean_tags(aggregated['tags'], number_of_tags)

        aggregated_list.append(aggregated)

    return aggregated_list

def aggregate_data_with_onu_and_sort(aggregated_list, articles_onu):
    updated_list = []

    for agg in aggregated_list:
        new_agg = agg.copy()
        date_agg = agg['date']

        for onu_article in articles_onu:
            date_onu = onu_article.get('date')

            if date_onu == date_agg:
                new_agg['death'] = onu_article.get('death')
                new_agg['injuried'] = onu_article.get('injuried')

        updated_list.append(new_agg)

    return sorted(updated_list, key=lambda x: x['date'])

# %%
mongo_db = connect_mongo(mongo_url, mongo_db_name)
collection_article_kiev = get_collection(mongo_db, mongo_collection_article_kiev)
collection_article_onu = get_collection(mongo_db, mongo_collection_article_onu)

articles_kiev = get_all_from_collection(collection_article_kiev)
articles_onu = get_all_from_collection(collection_article_onu)

list_aggregated = get_article_kiev_aggregated(articles_kiev, number_of_tags)
list_aggregated_with_onu_sorted = aggregate_data_with_onu_and_sort(list_aggregated, articles_onu)

# %%
list_aggregated_with_onu_sorted
# Out:
# [{'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'emailthe', 'count': 5},
#    {'title': 'company', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'russian', 'count': 2},
#    {'title': 'responsible', 'count': 1},
#    {'title': 'buying', 'count': 1}],
#   'date': datetime.datetime(2021, 11, 14, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'state', 'count': 2},
#    {'title': 'own', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'general', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 15, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'accord', 'count': 3},
#    {'title': 'would', 'count': 2},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'enter', 'count': 2},
#    {'title': 'operate', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 16, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'state', 'count': 2},
#    {'title': 'own', 'count': 2},
#    {'title': 'center', 'count': 2},
#    {'title': 'emailon', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 17, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 10,
#   'tags': [{'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'country', 'count': 3},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'round', 'count': 2},
#    {'title': 'report', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 18, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'expect', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'charge', 'count': 2},
#    {'title': 'emailaccording', 'count': 1}],
#   'date': datetime.datetime(2021, 11, 19, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'president', 'count': 2},
#    {'title': 'attack', 'count': 2},
#    {'title': 'military', 'count': 2},
#    {'title': 'chornobyl', 'count': 1}],
#   'date': datetime.datetime(2021, 11, 21, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'emailthe', 'count': 5},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'million', 'count': 2},
#    {'title': 'state', 'count': 2},
#    {'title': 'company', 'count': 2},
#    {'title': 'include', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 22, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'center', 'count': 2},
#    {'title': 'billion', 'count': 2},
#    {'title': 'payment', 'count': 2},
#    {'title': 'found', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 23, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'award', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'allocate', 'count': 2},
#    {'title': 'million', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 24, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 10,
#   'tags': [{'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'state', 'count': 4},
#    {'title': 'announce', 'count': 3},
#    {'title': 'volodymyr', 'count': 3},
#    {'title': 'zelensky', 'count': 3},
#    {'title': 'report', 'count': 3}],
#   'date': datetime.datetime(2021, 11, 25, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'zelensky', 'count': 2},
#    {'title': 'press', 'count': 2},
#    {'title': 'evening', 'count': 2},
#    {'title': 'emailgrammy', 'count': 1},
#    {'title': 'winning', 'count': 1},
#    {'title': 'singer', 'count': 1}],
#   'date': datetime.datetime(2021, 11, 26, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'state', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'video', 'count': 2},
#    {'title': 'journalist', 'count': 2},
#    {'title': 'emailfilmed', 'count': 1},
#    {'title': 'family', 'count': 1}],
#   'date': datetime.datetime(2021, 11, 28, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'emailthe', 'count': 4},
#    {'title': 'own', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'prize', 'count': 2},
#    {'title': 'company', 'count': 2},
#    {'title': 'add', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 29, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'minister', 'count': 3},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'second', 'count': 2},
#    {'title': 'covid-19', 'count': 2},
#    {'title': 'viktor', 'count': 2}],
#   'date': datetime.datetime(2021, 11, 30, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'president', 'count': 2},
#    {'title': 'volodymyr', 'count': 2},
#    {'title': 'zelensky', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'ukraine', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 1, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'delay', 'count': 2},
#    {'title': 'corruption', 'count': 2},
#    {'title': 'prosecutor', 'count': 2},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'state', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 2, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'million', 'count': 4},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'government', 'count': 2},
#    {'title': 'purchase', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'energy', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 3, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 2,
#   'tags': [{'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2},
#    {'title': 'emailas', 'count': 1},
#    {'title': 'crisis', 'count': 1},
#    {'title': 'russia', 'count': 1},
#    {'title': 'potential', 'count': 1},
#    {'title': 'scale', 'count': 1},
#    {'title': 'invasion', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 4, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 4,
#   'tags': [{'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailas', 'count': 1},
#    {'title': 'security', 'count': 1},
#    {'title': 'crisis', 'count': 1},
#    {'title': 'russia', 'count': 1},
#    {'title': 'continue', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 5, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'emaila', 'count': 1},
#    {'title': 'spreading', 'count': 1},
#    {'title': 'taking', 'count': 1},
#    {'title': 'advantage', 'count': 1},
#    {'title': 'government', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 6, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'emailthe', 'count': 4},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'ministry', 'count': 2},
#    {'title': 'announce', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'forward', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 7, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'military', 'count': 2},
#    {'title': 'russian', 'count': 2},
#    {'title': 'million', 'count': 2},
#    {'title': 'include', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 8, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'emailthe', 'count': 4},
#    {'title': 'accord', 'count': 3},
#    {'title': 'claim', 'count': 2},
#    {'title': 'official', 'count': 2},
#    {'title': 'president', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 9, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'president', 'count': 4},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'russian', 'count': 3},
#    {'title': 'volodymyr', 'count': 3},
#    {'title': 'zelensky', 'count': 3},
#    {'title': 'conference', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 10, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 3,
#   'tags': [{'title': 'share', 'count': 3},
#    {'title': 'twitter', 'count': 3},
#    {'title': 'facebook', 'count': 3},
#    {'title': 'linkedin', 'count': 3},
#    {'title': 'emaileditor', 'count': 1},
#    {'title': 'following', 'count': 1},
#    {'title': 'analytical', 'count': 1},
#    {'title': 'note', 'count': 1},
#    {'title': 'timothy', 'count': 1},
#    {'title': 'senior', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 11, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'emailthree', 'count': 1},
#    {'title': 'division', 'count': 1},
#    {'title': 'boxing', 'count': 1},
#    {'title': 'champion', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 12, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 4,
#   'tags': [{'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'military', 'count': 2},
#    {'title': 'emailnord', 'count': 1},
#    {'title': 'stream', 'count': 1},
#    {'title': 'billion', 'count': 1},
#    {'title': 'undersea', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 13, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'minister', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'covid-19', 'count': 3},
#    {'title': 'security', 'count': 2},
#    {'title': 'health', 'count': 2},
#    {'title': 'fully', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 14, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'court', 'count': 2},
#    {'title': 'former', 'count': 2},
#    {'title': 'investment', 'count': 2},
#    {'title': 'emailpresident', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 15, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 12,
#   'tags': [{'title': 'share', 'count': 12},
#    {'title': 'twitter', 'count': 12},
#    {'title': 'facebook', 'count': 12},
#    {'title': 'linkedin', 'count': 12},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'accord', 'count': 3},
#    {'title': 'sign', 'count': 3},
#    {'title': 'european', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'independent', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 16, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'crisis', 'count': 2},
#    {'title': 'security', 'count': 2},
#    {'title': 'international', 'count': 2},
#    {'title': 'ukrainian', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 17, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 3,
#   'tags': [{'title': 'share', 'count': 3},
#    {'title': 'twitter', 'count': 3},
#    {'title': 'facebook', 'count': 3},
#    {'title': 'linkedin', 'count': 3},
#    {'title': 'state', 'count': 2},
#    {'title': 'emaileditor', 'count': 1},
#    {'title': 'issue', 'count': 1},
#    {'title': 'ukrainian', 'count': 1},
#    {'title': 'own', 'count': 1},
#    {'title': 'enterprise', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 18, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'million', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'approve', 'count': 2},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'sign', 'count': 2},
#    {'title': 'agreement', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 19, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'accord', 'count': 2},
#    {'title': 'ministry', 'count': 2},
#    {'title': 'launch', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'emailukraine', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 20, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'million', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'accord', 'count': 2},
#    {'title': 'number', 'count': 2},
#    {'title': 'first', 'count': 2},
#    {'title': 'emailthe', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 21, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 10,
#   'tags': [{'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'russian', 'count': 4},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'court', 'count': 3},
#    {'title': 'action', 'count': 2},
#    {'title': 'state', 'count': 2},
#    {'title': 'emailthe', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 22, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'accord', 'count': 4},
#    {'title': 'state', 'count': 2},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'available', 'count': 2},
#    {'title': 'long', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 23, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 4,
#   'tags': [{'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'emaila', 'count': 2},
#    {'title': 'president', 'count': 2},
#    {'title': 'accord', 'count': 2},
#    {'title': 'publish', 'count': 2},
#    {'title': 'selection', 'count': 1},
#    {'title': 'panel', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 24, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 2,
#   'tags': [{'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2},
#    {'title': 'emaila', 'count': 1},
#    {'title': 'recent', 'count': 1},
#    {'title': 'order', 'count': 1},
#    {'title': 'defense', 'count': 1},
#    {'title': 'ministry', 'count': 1},
#    {'title': 'require', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 25, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 1,
#   'tags': [{'title': 'share', 'count': 1},
#    {'title': 'twitter', 'count': 1},
#    {'title': 'facebook', 'count': 1},
#    {'title': 'linkedin', 'count': 1},
#    {'title': 'emailthe', 'count': 1},
#    {'title': 'contemporary', 'count': 1},
#    {'title': 'history', 'count': 1},
#    {'title': 'soviet', 'count': 1},
#    {'title': 'country', 'count': 1},
#    {'title': 'eurasia', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 26, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'security', 'count': 3},
#    {'title': 'accord', 'count': 3},
#    {'title': 'russian', 'count': 2},
#    {'title': 'defense', 'count': 2},
#    {'title': 'record', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 27, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'first', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'million', 'count': 2},
#    {'title': 'force', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 28, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'energy', 'count': 2},
#    {'title': 'import', 'count': 2},
#    {'title': 'accord', 'count': 2},
#    {'title': 'outlet', 'count': 2},
#    {'title': 'ekonomichna', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 29, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'state', 'count': 3},
#    {'title': 'russia', 'count': 3},
#    {'title': 'independent', 'count': 3},
#    {'title': 'emailthe', 'count': 2}],
#   'date': datetime.datetime(2021, 12, 30, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 2,
#   'tags': [{'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2},
#    {'title': 'emaillieutenant', 'count': 1},
#    {'title': 'colonel', 'count': 1},
#    {'title': 'serhiy', 'count': 1},
#    {'title': 'koval', 'count': 1},
#    {'title': 'career', 'count': 1},
#    {'title': 'officer', 'count': 1}],
#   'date': datetime.datetime(2021, 12, 31, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 1,
#   'tags': [{'title': 'share', 'count': 1},
#    {'title': 'twitter', 'count': 1},
#    {'title': 'facebook', 'count': 1},
#    {'title': 'linkedin', 'count': 1},
#    {'title': 'emailoleksiy', 'count': 1},
#    {'title': 'sukhachov', 'count': 1},
#    {'title': 'state', 'count': 1},
#    {'title': 'investigation', 'count': 1},
#    {'title': 'bureau', 'count': 1},
#    {'title': 'president', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 1, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 2,
#   'tags': [{'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2},
#    {'title': 'emailafter', 'count': 1},
#    {'title': 'seven', 'count': 1},
#    {'title': 'years', 'count': 1},
#    {'title': 'ukraine', 'count': 1},
#    {'title': 'ban', 'count': 1},
#    {'title': 'russia', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 2, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'russia', 'count': 3},
#    {'title': 'military', 'count': 3},
#    {'title': 'border', 'count': 3},
#    {'title': 'foreign', 'count': 2},
#    {'title': 'russian', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 3, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'million', 'count': 2},
#    {'title': 'military', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'emailthe', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 4, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 4,
#   'tags': [{'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'emaileditor', 'count': 3},
#    {'title': 'following', 'count': 2},
#    {'title': 'independent', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'analytical', 'count': 1},
#    {'title': 'note', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 5, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 6,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'russian', 'count': 2},
#    {'title': 'president', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'country', 'count': 2},
#    {'title': 'state', 'count': 2},
#    {'title': 'ukraine', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 6, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'force', 'count': 2},
#    {'title': 'country', 'count': 2},
#    {'title': 'arm', 'count': 2},
#    {'title': 'accord', 'count': 2},
#    {'title': 'emaileditor', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 7, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'security', 'count': 2},
#    {'title': 'kazakh', 'count': 2},
#    {'title': 'publish', 'count': 2},
#    {'title': 'recent', 'count': 2},
#    {'title': 'emaileditor', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 8, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 3,
#   'tags': [{'title': 'share', 'count': 3},
#    {'title': 'twitter', 'count': 3},
#    {'title': 'facebook', 'count': 3},
#    {'title': 'linkedin', 'count': 3},
#    {'title': 'security', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'emailthe', 'count': 1},
#    {'title': 'unite', 'count': 1},
#    {'title': 'state', 'count': 1},
#    {'title': 'moscow', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 9, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'deputy', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'foreign', 'count': 1},
#    {'title': 'ministry', 'count': 1},
#    {'title': 'statement', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 10, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'accord', 'count': 3},
#    {'title': 'increase', 'count': 3},
#    {'title': 'state', 'count': 3},
#    {'title': 'russia', 'count': 3},
#    {'title': 'total', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 11, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'accord', 'count': 4},
#    {'title': 'world', 'count': 3},
#    {'title': 'people', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailrussia', 'count': 2},
#    {'title': 'deputy', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 12, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'investigation', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'report', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 13, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'russia', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailrussia', 'count': 2},
#    {'title': 'security', 'count': 2},
#    {'title': 'emailukraine', 'count': 2},
#    {'title': 'propose', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 14, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'report', 'count': 2},
#    {'title': 'ukrainian', 'count': 2},
#    {'title': 'emaileditor', 'count': 2},
#    {'title': 'latest', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 15, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 3,
#   'tags': [{'title': 'share', 'count': 3},
#    {'title': 'twitter', 'count': 3},
#    {'title': 'facebook', 'count': 3},
#    {'title': 'linkedin', 'count': 3},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'website', 'count': 2},
#    {'title': 'ministry', 'count': 1},
#    {'title': 'digital', 'count': 1},
#    {'title': 'transformation', 'count': 1},
#    {'title': 'point', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 16, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'president', 'count': 3},
#    {'title': 'state', 'count': 3},
#    {'title': 'nearly', 'count': 2},
#    {'title': 'emailukrainian', 'count': 2},
#    {'title': 'support', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 17, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6},
#    {'title': 'linkedin', 'count': 6},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'secretary', 'count': 3},
#    {'title': 'russia', 'count': 2},
#    {'title': 'invasion', 'count': 2},
#    {'title': 'western', 'count': 2},
#    {'title': 'state', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 18, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 5},
#    {'title': 'president', 'count': 3},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'confirm', 'count': 2},
#    {'title': 'ongoing', 'count': 2},
#    {'title': 'russian', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 19, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 16,
#   'tags': [{'title': 'share', 'count': 16},
#    {'title': 'twitter', 'count': 16},
#    {'title': 'facebook', 'count': 16},
#    {'title': 'linkedin', 'count': 16},
#    {'title': 'ukraine', 'count': 9},
#    {'title': 'russian', 'count': 4},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'emaileditor', 'count': 3},
#    {'title': 'following', 'count': 3}],
#   'date': datetime.datetime(2022, 1, 20, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 10,
#   'tags': [{'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'ukraine', 'count': 7},
#    {'title': 'russia', 'count': 5},
#    {'title': 'russian', 'count': 4},
#    {'title': 'state', 'count': 3},
#    {'title': 'invasion', 'count': 3},
#    {'title': 'european', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 21, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'share', 'count': 7},
#    {'title': 'twitter', 'count': 7},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'linkedin', 'count': 7},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'president', 'count': 2},
#    {'title': 'state', 'count': 2},
#    {'title': 'emaileditor', 'count': 2},
#    {'title': 'independent', 'count': 2},
#    {'title': 'allies', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 22, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 3,
#   'tags': [{'title': 'share', 'count': 3},
#    {'title': 'twitter', 'count': 3},
#    {'title': 'facebook', 'count': 3},
#    {'title': 'linkedin', 'count': 3},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'russian', 'count': 2},
#    {'title': 'emailspanish', 'count': 1},
#    {'title': 'delivery', 'count': 1},
#    {'title': 'service', 'count': 1},
#    {'title': 'glovo', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 23, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 10,
#   'tags': [{'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'russian', 'count': 5},
#    {'title': 'emaileditor', 'count': 4},
#    {'title': 'president', 'count': 4},
#    {'title': 'publish', 'count': 3},
#    {'title': 'fear', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 24, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'unite', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'military', 'count': 2},
#    {'title': 'ukrainian', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 25, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 9,
#   'tags': [{'title': 'share', 'count': 9},
#    {'title': 'twitter', 'count': 9},
#    {'title': 'facebook', 'count': 9},
#    {'title': 'linkedin', 'count': 9},
#    {'title': 'russia', 'count': 6},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'state', 'count': 3},
#    {'title': 'secretary', 'count': 2},
#    {'title': 'president', 'count': 2},
#    {'title': 'country', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 26, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 15,
#   'tags': [{'title': 'share', 'count': 15},
#    {'title': 'twitter', 'count': 15},
#    {'title': 'facebook', 'count': 15},
#    {'title': 'linkedin', 'count': 15},
#    {'title': 'ukraine', 'count': 6},
#    {'title': 'publish', 'count': 3},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'russia', 'count': 3},
#    {'title': 'invasion', 'count': 3},
#    {'title': 'emaileditor', 'count': 2}],
#   'date': datetime.datetime(2022, 1, 27, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 8,
#   'tags': [{'title': 'share', 'count': 8},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 8},
#    {'title': 'linkedin', 'count': 8},
#    {'title': 'ukraine', 'count': 4},
#    {'title': 'russian', 'count': 3},
#    {'title': 'russia', 'count': 3},
#    {'title': 'volodymyr', 'count': 3},
#    {'title': 'zelensky', 'count': 3},
#    {'title': 'president', 'count': 3}],
#   'date': datetime.datetime(2022, 1, 28, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 3,
#   'tags': [{'title': 'share', 'count': 3},
#    {'title': 'twitter', 'count': 3},
#    {'title': 'facebook', 'count': 3},
#    {'title': 'linkedin', 'count': 3},
#    {'title': 'since', 'count': 2},
#    {'title': 'emaila', 'count': 1},
#    {'title': 'sword', 'count': 1},
#    {'title': 'damocles', 'count': 1},
#    {'title': 'hang', 'count': 1},
#    {'title': 'ukraine', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 29, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 2,
#   'tags': [{'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2},
#    {'title': 'ukraine', 'count': 2},
#    {'title': 'emaileditor', 'count': 1},
#    {'title': 'following', 'count': 1},
#    {'title': 'latest', 'count': 1},
#    {'title': 'edition', 'count': 1},
#    {'title': 'independent', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 30, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 5,
#   'tags': [{'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukraine', 'count': 3},
#    {'title': 'emailthe', 'count': 2},
#    {'title': 'emaileditor', 'count': 2},
#    {'title': 'permission', 'count': 2},
#    {'title': 'russia', 'count': 2},
#    {'title': 'prosecutor', 'count': 1}],
#   'date': datetime.datetime(2022, 1, 31, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 11,
#   'tags': [{'title': 'share', 'count': 11},
#    {'title': 'twitter', 'count': 11},
#    {'title': 'facebook', 'count': 11},
#    {'title': 'linkedin', 'count': 11},
#    {'title': 'ukraine', 'count': 7},
#    {'title': 'emailthe', 'count': 3},
#    {'title': 'unite', 'count': 3},
#    {'title': 'first', 'count': 2},
#    {'title': 'president', 'count': 2},
#    {'title': 'state', 'count': 2}],
#   'date': datetime.datetime(2022, 2, 1, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 7,
#   'tags': [{'title': 'ukraine', 'count': 4},
#    {'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'russia', 'count': 3},
#    {'title': 'emaileditor', 'count': 2},
#    {'title': 'minister', 'count': 2},
#    {'title': 'threat', 'count': 1},
#    {'title': 'invasion', 'count': 1}],
#   'date': datetime.datetime(2022, 2, 2, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 24,
#   'tags': [{'title': 'ukraine', 'count': 13},
#    {'title': 'ukrainian', 'count': 5},
#    {'title': 'russia', 'count': 5},
#    {'title': 'russian', 'count': 4},
#    {'title': 'defense', 'count': 3},
#    {'title': 'open', 'count': 3},
#    {'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2}],
#   'date': datetime.datetime(2022, 2, 3, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 29,
#   'tags': [{'title': 'ukraine', 'count': 12},
#    {'title': 'russia', 'count': 11},
#    {'title': 'russian', 'count': 7},
#    {'title': 'president', 'count': 6},
#    {'title': 'share', 'count': 5},
#    {'title': 'twitter', 'count': 5},
#    {'title': 'facebook', 'count': 5},
#    {'title': 'linkedin', 'count': 5},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'vladimir', 'count': 4}],
#   'date': datetime.datetime(2022, 2, 4, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 11,
#   'tags': [{'title': 'ukraine', 'count': 5},
#    {'title': 'ukrainian', 'count': 3},
#    {'title': 'share', 'count': 2},
#    {'title': 'twitter', 'count': 2},
#    {'title': 'facebook', 'count': 2},
#    {'title': 'linkedin', 'count': 2},
#    {'title': 'kharkiv', 'count': 2},
#    {'title': 'include', 'count': 2},
#    {'title': 'scale', 'count': 2},
#    {'title': 'military', 'count': 2}],
#   'date': datetime.datetime(2022, 2, 5, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 13,
#   'tags': [{'title': 'ukraine', 'count': 7},
#    {'title': 'russia', 'count': 6},
#    {'title': 'report', 'count': 5},
#    {'title': 'military', 'count': 3},
#    {'title': 'border', 'count': 3},
#    {'title': 'russian', 'count': 3},
#    {'title': 'invasion', 'count': 3},
#    {'title': 'cite', 'count': 3},
#    {'title': 'official', 'count': 3},
#    {'title': 'attack', 'count': 3}],
#   'date': datetime.datetime(2022, 2, 6, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 25,
#   'tags': [{'title': 'ukraine', 'count': 9},
#    {'title': 'russian', 'count': 6},
#    {'title': 'state', 'count': 5},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'troops', 'count': 3},
#    {'title': 'russia', 'count': 3},
#    {'title': 'accord', 'count': 3},
#    {'title': 'serhii', 'count': 3},
#    {'title': 'national', 'count': 3},
#    {'title': 'bureau', 'count': 3}],
#   'date': datetime.datetime(2022, 2, 7, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 23,
#   'tags': [{'title': 'russia', 'count': 12},
#    {'title': 'ukraine', 'count': 12},
#    {'title': 'president', 'count': 9},
#    {'title': 'ukrainian', 'count': 7},
#    {'title': 'russian', 'count': 7},
#    {'title': 'border', 'count': 4},
#    {'title': 'military', 'count': 4},
#    {'title': 'french', 'count': 4},
#    {'title': 'zelensky', 'count': 4},
#    {'title': 'minsk', 'count': 4}],
#   'date': datetime.datetime(2022, 2, 8, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 22,
#   'tags': [{'title': 'russia', 'count': 9},
#    {'title': 'ukraine', 'count': 7},
#    {'title': 'country', 'count': 5},
#    {'title': 'people', 'count': 5},
#    {'title': 'military', 'count': 4},
#    {'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'week', 'count': 3}],
#   'date': datetime.datetime(2022, 2, 9, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 19,
#   'tags': [{'title': 'ukraine', 'count': 9},
#    {'title': 'ukrainian', 'count': 5},
#    {'title': 'accord', 'count': 4},
#    {'title': 'russia', 'count': 4},
#    {'title': 'country', 'count': 4},
#    {'title': 'russian', 'count': 3},
#    {'title': 'council', 'count': 2},
#    {'title': 'medium', 'count': 2},
#    {'title': 'minister', 'count': 2},
#    {'title': 'personnel', 'count': 2}],
#   'date': datetime.datetime(2022, 2, 10, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 39,
#   'tags': [{'title': 'ukraine', 'count': 18},
#    {'title': 'russia', 'count': 12},
#    {'title': 'russian', 'count': 12},
#    {'title': 'would', 'count': 7},
#    {'title': 'security', 'count': 6},
#    {'title': 'could', 'count': 6},
#    {'title': 'continue', 'count': 6},
#    {'title': 'report', 'count': 6},
#    {'title': 'invasion', 'count': 6},
#    {'title': 'leave', 'count': 5}],
#   'date': datetime.datetime(2022, 2, 11, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 25,
#   'tags': [{'title': 'ukraine', 'count': 16},
#    {'title': 'russian', 'count': 11},
#    {'title': 'invasion', 'count': 9},
#    {'title': 'russia', 'count': 7},
#    {'title': 'state', 'count': 7},
#    {'title': 'military', 'count': 7},
#    {'title': 'country', 'count': 6},
#    {'title': 'share', 'count': 6},
#    {'title': 'twitter', 'count': 6},
#    {'title': 'facebook', 'count': 6}],
#   'date': datetime.datetime(2022, 2, 12, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 22,
#   'tags': [{'title': 'ukraine', 'count': 11},
#    {'title': 'ukrainian', 'count': 7},
#    {'title': 'russian', 'count': 5},
#    {'title': 'russia', 'count': 4},
#    {'title': 'accord', 'count': 4},
#    {'title': 'flight', 'count': 4},
#    {'title': 'company', 'count': 4},
#    {'title': 'foreign', 'count': 4},
#    {'title': 'minister', 'count': 4},
#    {'title': 'longer', 'count': 3}],
#   'date': datetime.datetime(2022, 2, 13, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 22,
#   'tags': [{'title': 'ukraine', 'count': 12},
#    {'title': 'russian', 'count': 8},
#    {'title': 'country', 'count': 7},
#    {'title': 'invasion', 'count': 6},
#    {'title': 'russia', 'count': 6},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'government', 'count': 4},
#    {'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4}],
#   'date': datetime.datetime(2022, 2, 14, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 26,
#   'tags': [{'title': 'ukraine', 'count': 15},
#    {'title': 'russian', 'count': 10},
#    {'title': 'russia', 'count': 6},
#    {'title': 'president', 'count': 5},
#    {'title': 'state', 'count': 5},
#    {'title': 'share', 'count': 4},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'facebook', 'count': 4},
#    {'title': 'linkedin', 'count': 4},
#    {'title': 'vladimir', 'count': 4}],
#   'date': datetime.datetime(2022, 2, 15, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 22,
#   'tags': [{'title': 'ukraine', 'count': 9},
#    {'title': 'russian', 'count': 7},
#    {'title': 'ukrainian', 'count': 6},
#    {'title': 'russia', 'count': 5},
#    {'title': 'military', 'count': 5},
#    {'title': 'president', 'count': 4},
#    {'title': 'attack', 'count': 3},
#    {'title': 'state', 'count': 3},
#    {'title': 'volodymyr', 'count': 3},
#    {'title': 'zelensky', 'count': 3}],
#   'date': datetime.datetime(2022, 2, 16, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 27,
#   'tags': [{'title': 'ukraine', 'count': 11},
#    {'title': 'russian', 'count': 6},
#    {'title': 'ukrainian', 'count': 6},
#    {'title': 'accord', 'count': 5},
#    {'title': 'russia', 'count': 5},
#    {'title': 'secretary', 'count': 4},
#    {'title': 'president', 'count': 4},
#    {'title': 'shelling', 'count': 4},
#    {'title': 'official', 'count': 4},
#    {'title': 'report', 'count': 4}],
#   'date': datetime.datetime(2022, 2, 17, 0, 0),
#   'deathCounts': 0},
#  {'articlesCount': 31,
#   'tags': [{'title': 'ukraine', 'count': 19},
#    {'title': 'russian', 'count': 12},
#    {'title': 'russia', 'count': 12},
#    {'title': 'report', 'count': 6},
#    {'title': 'proxy', 'count': 6},
#    {'title': 'occupy', 'count': 6},
#    {'title': 'force', 'count': 6},
#    {'title': 'intelligence', 'count': 5},
#    {'title': 'area', 'count': 5},
#    {'title': 'kremlin', 'count': 5}],
#   'date': datetime.datetime(2022, 2, 18, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 33,
#   'tags': [{'title': 'ukraine', 'count': 20},
#    {'title': 'russia', 'count': 19},
#    {'title': 'russian', 'count': 12},
#    {'title': 'munich', 'count': 7},
#    {'title': 'security', 'count': 7},
#    {'title': 'conference', 'count': 7},
#    {'title': 'ukrainian', 'count': 7},
#    {'title': 'invade', 'count': 7},
#    {'title': 'military', 'count': 6},
#    {'title': 'accord', 'count': 6}],
#   'date': datetime.datetime(2022, 2, 19, 0, 0),
#   'deathCounts': 2},
#  {'articlesCount': 22,
#   'tags': [{'title': 'ukraine', 'count': 15},
#    {'title': 'russia', 'count': 10},
#    {'title': 'russian', 'count': 7},
#    {'title': 'donbas', 'count': 7},
#    {'title': 'military', 'count': 6},
#    {'title': 'proxy', 'count': 6},
#    {'title': 'twitter', 'count': 4},
#    {'title': 'ukrainian', 'count': 4},
#    {'title': 'include', 'count': 4},
#    {'title': 'force', 'count': 4}],
#   'date': datetime.datetime(2022, 2, 20, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 47,
#   'tags': [{'title': 'ukraine', 'count': 26},
#    {'title': 'russian', 'count': 22},
#    {'title': 'russia', 'count': 15},
#    {'title': 'state', 'count': 15},
#    {'title': 'president', 'count': 14},
#    {'title': 'recognize', 'count': 12},
#    {'title': 'occupy', 'count': 12},
#    {'title': 'independent', 'count': 10},
#    {'title': 'territory', 'count': 9},
#    {'title': 'security', 'count': 9}],
#   'date': datetime.datetime(2022, 2, 21, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 51,
#   'tags': [{'title': 'ukraine', 'count': 22},
#    {'title': 'russia', 'count': 20},
#    {'title': 'russian', 'count': 19},
#    {'title': 'occupy', 'count': 17},
#    {'title': 'kremlin', 'count': 13},
#    {'title': 'recognize', 'count': 13},
#    {'title': 'president', 'count': 12},
#    {'title': 'eastern', 'count': 12},
#    {'title': 'twitter', 'count': 11},
#    {'title': 'share', 'count': 10}],
#   'date': datetime.datetime(2022, 2, 22, 0, 0),
#   'deathCounts': 2},
#  {'articlesCount': 47,
#   'tags': [{'title': 'ukraine', 'count': 23},
#    {'title': 'russia', 'count': 22},
#    {'title': 'russian', 'count': 17},
#    {'title': 'ukrainian', 'count': 10},
#    {'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'minister', 'count': 9},
#    {'title': 'military', 'count': 8}],
#   'date': datetime.datetime(2022, 2, 23, 0, 0),
#   'deathCounts': 1},
#  {'articlesCount': 77,
#   'tags': [{'title': 'ukraine', 'count': 30},
#    {'title': 'russia', 'count': 25},
#    {'title': 'russian', 'count': 24},
#    {'title': 'military', 'count': 20},
#    {'title': 'president', 'count': 14},
#    {'title': 'ukrainian', 'count': 13},
#    {'title': 'report', 'count': 13},
#    {'title': 'people', 'count': 13},
#    {'title': 'attack', 'count': 11},
#    {'title': 'would', 'count': 9}],
#   'date': datetime.datetime(2022, 2, 24, 0, 0),
#   'deathCounts': 6},
#  {'articlesCount': 77,
#   'tags': [{'title': 'ukraine', 'count': 29},
#    {'title': 'russian', 'count': 25},
#    {'title': 'russia', 'count': 20},
#    {'title': 'ukrainian', 'count': 19},
#    {'title': 'force', 'count': 18},
#    {'title': 'military', 'count': 12},
#    {'title': 'president', 'count': 12},
#    {'title': 'country', 'count': 11},
#    {'title': 'state', 'count': 11},
#    {'title': 'people', 'count': 11}],
#   'date': datetime.datetime(2022, 2, 25, 0, 0),
#   'deathCounts': 4},
#  {'articlesCount': 82,
#   'tags': [{'title': 'ukraine', 'count': 39},
#    {'title': 'russian', 'count': 25},
#    {'title': 'force', 'count': 19},
#    {'title': 'report', 'count': 18},
#    {'title': 'russia', 'count': 18},
#    {'title': 'accord', 'count': 16},
#    {'title': 'ukrainian', 'count': 15},
#    {'title': 'state', 'count': 12},
#    {'title': 'twitter', 'count': 11},
#    {'title': 'heavy', 'count': 10}],
#   'date': datetime.datetime(2022, 2, 26, 0, 0),
#   'deathCounts': 4},
#  {'articlesCount': 91,
#   'tags': [{'title': 'ukraine', 'count': 33},
#    {'title': 'russian', 'count': 31},
#    {'title': 'russia', 'count': 24},
#    {'title': 'ukrainian', 'count': 17},
#    {'title': 'president', 'count': 15},
#    {'title': 'accord', 'count': 15},
#    {'title': 'force', 'count': 14},
#    {'title': 'military', 'count': 12},
#    {'title': 'report', 'count': 11},
#    {'title': 'state', 'count': 9}],
#   'date': datetime.datetime(2022, 2, 27, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 102,
#    'men': 1,
#    'women': 14,
#    'girls': 2,
#    'boys': 3,
#    'children': 2,
#    'adults': 66},
#   'injuried': {'total': 304,
#    'men': 2,
#    'women': 18,
#    'girls': 5,
#    'boys': 2,
#    'children': 14,
#    'adults': 239}},
#  {'articlesCount': 63,
#   'tags': [{'title': 'ukraine', 'count': 30},
#    {'title': 'russian', 'count': 22},
#    {'title': 'russia', 'count': 21},
#    {'title': 'accord', 'count': 13},
#    {'title': 'force', 'count': 10},
#    {'title': 'share', 'count': 10},
#    {'title': 'twitter', 'count': 10},
#    {'title': 'facebook', 'count': 10},
#    {'title': 'linkedin', 'count': 10},
#    {'title': 'ukrainian', 'count': 10}],
#   'date': datetime.datetime(2022, 2, 28, 0, 0),
#   'deathCounts': 1,
#   'death': {'total': 142,
#    'men': 2,
#    'women': 19,
#    'girls': 3,
#    'boys': 4,
#    'children': 6,
#    'adults': 88},
#   'injuried': {'total': 408,
#    'men': 3,
#    'women': 25,
#    'girls': 6,
#    'boys': 2,
#    'children': 18,
#    'adults': 321}},
#  {'articlesCount': 64,
#   'tags': [{'title': 'ukraine', 'count': 27},
#    {'title': 'accord', 'count': 21},
#    {'title': 'russian', 'count': 20},
#    {'title': 'russia', 'count': 17},
#    {'title': 'president', 'count': 12},
#    {'title': 'state', 'count': 12},
#    {'title': 'force', 'count': 11},
#    {'title': 'ukrainian', 'count': 9},
#    {'title': 'zelensky', 'count': 8},
#    {'title': 'missile', 'count': 8}],
#   'date': datetime.datetime(2022, 3, 1, 0, 0),
#   'deathCounts': 2},
#  {'articlesCount': 68,
#   'tags': [{'title': 'russian', 'count': 36},
#    {'title': 'ukraine', 'count': 35},
#    {'title': 'accord', 'count': 25},
#    {'title': 'russia', 'count': 25},
#    {'title': 'ukrainian', 'count': 13},
#    {'title': 'force', 'count': 13},
#    {'title': 'state', 'count': 12},
#    {'title': 'country', 'count': 10},
#    {'title': 'sanction', 'count': 10},
#    {'title': 'people', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 2, 0, 0),
#   'deathCounts': 6,
#   'death': None,
#   'injuried': None},
#  {'articlesCount': 54,
#   'tags': [{'title': 'ukraine', 'count': 30},
#    {'title': 'russian', 'count': 23},
#    {'title': 'russia', 'count': 23},
#    {'title': 'accord', 'count': 15},
#    {'title': 'president', 'count': 9},
#    {'title': 'ukrainian', 'count': 9},
#    {'title': 'state', 'count': 8},
#    {'title': 'unite', 'count': 7},
#    {'title': 'nation', 'count': 7},
#    {'title': 'force', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 3, 0, 0),
#   'deathCounts': 2,
#   'death': {'total': 331,
#    'men': 7,
#    'women': 40,
#    'girls': 3,
#    'boys': 7,
#    'children': 9,
#    'adults': 201},
#   'injuried': {'total': 675,
#    'men': 5,
#    'women': 40,
#    'girls': 9,
#    'boys': 2,
#    'children': 20,
#    'adults': 553}},
#  {'articlesCount': 49,
#   'tags': [{'title': 'ukraine', 'count': 20},
#    {'title': 'russian', 'count': 16},
#    {'title': 'accord', 'count': 14},
#    {'title': 'russia', 'count': 14},
#    {'title': 'president', 'count': 11},
#    {'title': 'ukrainian', 'count': 10},
#    {'title': 'march', 'count': 9},
#    {'title': 'twitter', 'count': 8},
#    {'title': 'facebook', 'count': 7},
#    {'title': 'zelensky', 'count': 6}],
#   'date': datetime.datetime(2022, 3, 4, 0, 0),
#   'deathCounts': 2,
#   'death': {'total': 351,
#    'men': 7,
#    'women': 41,
#    'girls': 4,
#    'boys': 8,
#    'children': 10,
#    'adults': 217},
#   'injuried': {'total': 707,
#    'men': 5,
#    'women': 40,
#    'girls': 11,
#    'boys': 2,
#    'children': 23,
#    'adults': 573}},
#  {'articlesCount': 52,
#   'tags': [{'title': 'ukraine', 'count': 22},
#    {'title': 'russian', 'count': 21},
#    {'title': 'accord', 'count': 15},
#    {'title': 'russia', 'count': 14},
#    {'title': 'ukrainian', 'count': 9},
#    {'title': 'force', 'count': 8},
#    {'title': 'civilian', 'count': 7},
#    {'title': 'putin', 'count': 6},
#    {'title': 'announce', 'count': 6},
#    {'title': 'march', 'count': 6}],
#   'date': datetime.datetime(2022, 3, 5, 0, 0),
#   'deathCounts': 2,
#   'death': {'total': 364,
#    'men': 7,
#    'women': 42,
#    'girls': 4,
#    'boys': 8,
#    'children': 13,
#    'adults': 223},
#   'injuried': {'total': 759,
#    'men': 6,
#    'women': 48,
#    'girls': 11,
#    'boys': 2,
#    'children': 28,
#    'adults': 603}},
#  {'articlesCount': 47,
#   'tags': [{'title': 'russian', 'count': 23},
#    {'title': 'ukraine', 'count': 22},
#    {'title': 'russia', 'count': 17},
#    {'title': 'accord', 'count': 14},
#    {'title': 'march', 'count': 12},
#    {'title': 'ukrainian', 'count': 8},
#    {'title': 'force', 'count': 8},
#    {'title': 'country', 'count': 7},
#    {'title': 'place', 'count': 6},
#    {'title': 'people', 'count': 5}],
#   'date': datetime.datetime(2022, 3, 6, 0, 0),
#   'deathCounts': 4,
#   'death': {'total': 406,
#    'men': 7,
#    'women': 45,
#    'girls': 4,
#    'boys': 8,
#    'children': 15,
#    'adults': 257},
#   'injuried': {'total': 801,
#    'men': 7,
#    'women': 51,
#    'girls': 11,
#    'boys': 2,
#    'children': 29,
#    'adults': 636}},
#  {'articlesCount': 61,
#   'tags': [{'title': 'ukraine', 'count': 24},
#    {'title': 'accord', 'count': 21},
#    {'title': 'russian', 'count': 21},
#    {'title': 'russia', 'count': 19},
#    {'title': 'march', 'count': 18},
#    {'title': 'minister', 'count': 12},
#    {'title': 'country', 'count': 11},
#    {'title': 'state', 'count': 9},
#    {'title': 'president', 'count': 8},
#    {'title': 'ukrainian', 'count': 8}],
#   'date': datetime.datetime(2022, 3, 7, 0, 0),
#   'deathCounts': 2,
#   'death': {'total': 474,
#    'men': 9,
#    'women': 54,
#    'girls': 4,
#    'boys': 8,
#    'children': 17,
#    'adults': 294},
#   'injuried': {'total': 861,
#    'men': 7,
#    'women': 55,
#    'girls': 11,
#    'boys': 3,
#    'children': 30,
#    'adults': 686}},
#  {'articlesCount': 58,
#   'tags': [{'title': 'ukraine', 'count': 28},
#    {'title': 'russia', 'count': 22},
#    {'title': 'russian', 'count': 21},
#    {'title': 'march', 'count': 19},
#    {'title': 'ukrainian', 'count': 12},
#    {'title': 'report', 'count': 11},
#    {'title': 'military', 'count': 9},
#    {'title': 'include', 'count': 8},
#    {'title': 'country', 'count': 8},
#    {'title': 'minister', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 8, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 516,
#    'men': 9,
#    'women': 60,
#    'girls': 5,
#    'boys': 9,
#    'children': 23,
#    'adults': 321},
#   'injuried': {'total': 908,
#    'men': 7,
#    'women': 57,
#    'girls': 12,
#    'boys': 4,
#    'children': 34,
#    'adults': 723}},
#  {'articlesCount': 44,
#   'tags': [{'title': 'russian', 'count': 15},
#    {'title': 'russia', 'count': 13},
#    {'title': 'ukraine', 'count': 13},
#    {'title': 'march', 'count': 12},
#    {'title': 'force', 'count': 9},
#    {'title': 'civilian', 'count': 9},
#    {'title': 'accord', 'count': 7},
#    {'title': 'ukrainian', 'count': 7},
#    {'title': 'announce', 'count': 6},
#    {'title': 'authorities', 'count': 5}],
#   'date': datetime.datetime(2022, 3, 9, 0, 0),
#   'deathCounts': 2,
#   'death': {'total': 549,
#    'men': 10,
#    'women': 67,
#    'girls': 6,
#    'boys': 9,
#    'children': 26,
#    'adults': 340},
#   'injuried': {'total': 957,
#    'men': 8,
#    'women': 64,
#    'girls': 14,
#    'boys': 4,
#    'children': 34,
#    'adults': 760}},
#  {'articlesCount': 64,
#   'tags': [{'title': 'russian', 'count': 31},
#    {'title': 'ukraine', 'count': 21},
#    {'title': 'russia', 'count': 19},
#    {'title': 'march', 'count': 17},
#    {'title': 'state', 'count': 16},
#    {'title': 'force', 'count': 15},
#    {'title': 'accord', 'count': 14},
#    {'title': 'minister', 'count': 9},
#    {'title': 'ukrainian', 'count': 9},
#    {'title': 'mariupol', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 10, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 564,
#    'men': 10,
#    'women': 73,
#    'girls': 6,
#    'boys': 9,
#    'children': 26,
#    'adults': 344},
#   'injuried': {'total': 982,
#    'men': 8,
#    'women': 67,
#    'girls': 14,
#    'boys': 4,
#    'children': 34,
#    'adults': 780}},
#  {'articlesCount': 59,
#   'tags': [{'title': 'russian', 'count': 25},
#    {'title': 'ukraine', 'count': 25},
#    {'title': 'accord', 'count': 21},
#    {'title': 'russia', 'count': 20},
#    {'title': 'president', 'count': 11},
#    {'title': 'report', 'count': 11},
#    {'title': 'force', 'count': 11},
#    {'title': 'march', 'count': 11},
#    {'title': 'state', 'count': 10},
#    {'title': 'ukrainian', 'count': 8}],
#   'date': datetime.datetime(2022, 3, 11, 0, 0),
#   'deathCounts': 5,
#   'death': {'total': 579,
#    'men': 11,
#    'women': 75,
#    'girls': 6,
#    'boys': 9,
#    'children': 27,
#    'adults': 352},
#   'injuried': {'total': 1002,
#    'men': 8,
#    'women': 68,
#    'girls': 14,
#    'boys': 4,
#    'children': 36,
#    'adults': 795}},
#  {'articlesCount': 54,
#   'tags': [{'title': 'ukraine', 'count': 20},
#    {'title': 'russian', 'count': 19},
#    {'title': 'accord', 'count': 16},
#    {'title': 'russia', 'count': 16},
#    {'title': 'march', 'count': 13},
#    {'title': 'ukrainian', 'count': 11},
#    {'title': 'force', 'count': 11},
#    {'title': 'president', 'count': 11},
#    {'title': 'military', 'count': 9},
#    {'title': 'report', 'count': 8}],
#   'date': datetime.datetime(2022, 3, 12, 0, 0),
#   'deathCounts': 2,
#   'death': {'total': 596,
#    'men': 12,
#    'women': 85,
#    'girls': 6,
#    'boys': 10,
#    'children': 27,
#    'adults': 344},
#   'injuried': {'total': 1067,
#    'men': 9,
#    'women': 69,
#    'girls': 14,
#    'boys': 4,
#    'children': 39,
#    'adults': 844}},
#  {'articlesCount': 48,
#   'tags': [{'title': 'russian', 'count': 21},
#    {'title': 'march', 'count': 19},
#    {'title': 'russia', 'count': 15},
#    {'title': 'accord', 'count': 15},
#    {'title': 'ukraine', 'count': 13},
#    {'title': 'kill', 'count': 10},
#    {'title': 'oblast', 'count': 8},
#    {'title': 'ukrainian', 'count': 8},
#    {'title': 'military', 'count': 7},
#    {'title': 'report', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 13, 0, 0),
#   'deathCounts': 8,
#   'death': {'total': 636,
#    'men': 12,
#    'women': 91,
#    'girls': 6,
#    'boys': 10,
#    'children': 30,
#    'adults': 372},
#   'injuried': {'total': 1125,
#    'men': 10,
#    'women': 71,
#    'girls': 15,
#    'boys': 4,
#    'children': 43,
#    'adults': 891}},
#  {'articlesCount': 64,
#   'tags': [{'title': 'russia', 'count': 22},
#    {'title': 'russian', 'count': 20},
#    {'title': 'ukraine', 'count': 19},
#    {'title': 'march', 'count': 17},
#    {'title': 'ukrainian', 'count': 15},
#    {'title': 'accord', 'count': 14},
#    {'title': 'military', 'count': 7},
#    {'title': 'mariupol', 'count': 7},
#    {'title': 'deputy', 'count': 7},
#    {'title': 'minister', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 14, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 691,
#    'men': 13,
#    'women': 99,
#    'girls': 7,
#    'boys': 11,
#    'children': 30,
#    'adults': 409},
#   'injuried': {'total': 1143,
#    'men': 10,
#    'women': 73,
#    'girls': 15,
#    'boys': 4,
#    'children': 43,
#    'adults': 903}},
#  {'articlesCount': 61,
#   'tags': [{'title': 'russian', 'count': 26},
#    {'title': 'march', 'count': 25},
#    {'title': 'ukraine', 'count': 21},
#    {'title': 'accord', 'count': 19},
#    {'title': 'russia', 'count': 12},
#    {'title': 'oblast', 'count': 9},
#    {'title': 'state', 'count': 9},
#    {'title': 'injure', 'count': 8},
#    {'title': 'governor', 'count': 8},
#    {'title': 'invasion', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 15, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 726,
#    'men': 14,
#    'women': 104,
#    'girls': 7,
#    'boys': 13,
#    'children': 32,
#    'adults': 429},
#   'injuried': {'total': 1174,
#    'men': 10,
#    'women': 77,
#    'girls': 15,
#    'boys': 4,
#    'children': 44,
#    'adults': 927}},
#  {'articlesCount': 54,
#   'tags': [{'title': 'ukraine', 'count': 26},
#    {'title': 'russian', 'count': 21},
#    {'title': 'accord', 'count': 16},
#    {'title': 'russia', 'count': 14},
#    {'title': 'march', 'count': 13},
#    {'title': 'ukrainian', 'count': 9},
#    {'title': 'state', 'count': 8},
#    {'title': 'minister', 'count': 7},
#    {'title': 'report', 'count': 7},
#    {'title': 'force', 'count': 6}],
#   'date': datetime.datetime(2022, 3, 16, 0, 0),
#   'deathCounts': 1,
#   'death': {'total': 780,
#    'men': 14,
#    'women': 111,
#    'girls': 7,
#    'boys': 15,
#    'children': 36,
#    'adults': 465},
#   'injuried': {'total': 1252,
#    'men': 13,
#    'women': 100,
#    'girls': 17,
#    'boys': 7,
#    'children': 44,
#    'adults': 954}},
#  {'articlesCount': 59,
#   'tags': [{'title': 'march', 'count': 35},
#    {'title': 'russian', 'count': 22},
#    {'title': 'ukraine', 'count': 21},
#    {'title': 'russia', 'count': 21},
#    {'title': 'accord', 'count': 15},
#    {'title': 'report', 'count': 11},
#    {'title': 'ukrainian', 'count': 9},
#    {'title': 'force', 'count': 9},
#    {'title': 'country', 'count': 8},
#    {'title': 'child', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 17, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 816,
#    'men': 15,
#    'women': 116,
#    'girls': 7,
#    'boys': 16,
#    'children': 36,
#    'adults': 489},
#   'injuried': {'total': 1333,
#    'men': 13,
#    'women': 104,
#    'girls': 17,
#    'boys': 7,
#    'children': 50,
#    'adults': 1022}},
#  {'articlesCount': 53,
#   'tags': [{'title': 'ukraine', 'count': 24},
#    {'title': 'russian', 'count': 23},
#    {'title': 'accord', 'count': 22},
#    {'title': 'russia', 'count': 16},
#    {'title': 'march', 'count': 15},
#    {'title': 'ukrainian', 'count': 14},
#    {'title': 'military', 'count': 12},
#    {'title': 'force', 'count': 11},
#    {'title': 'country', 'count': 8},
#    {'title': 'million', 'count': 7}],
#   'date': datetime.datetime(2022, 3, 18, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 847,
#    'men': 15,
#    'women': 119,
#    'girls': 7,
#    'boys': 21,
#    'children': 36,
#    'adults': 509},
#   'injuried': {'total': 1399,
#    'men': 14,
#    'women': 107,
#    'girls': 18,
#    'boys': 9,
#    'children': 51,
#    'adults': 1072}},
#  {'articlesCount': 35,
#   'tags': [{'title': 'march', 'count': 18},
#    {'title': 'ukraine', 'count': 13},
#    {'title': 'russian', 'count': 12},
#    {'title': 'russia', 'count': 10},
#    {'title': 'accord', 'count': 6},
#    {'title': 'ukrainian', 'count': 6},
#    {'title': 'minister', 'count': 6},
#    {'title': 'missile', 'count': 5},
#    {'title': 'report', 'count': 5},
#    {'title': 'include', 'count': 5}],
#   'date': datetime.datetime(2022, 3, 19, 0, 0),
#   'deathCounts': 3,
#   'death': {'total': 902,
#    'men': 17,
#    'women': 134,
#    'girls': 11,
#    'boys': 25,
#    'children': 39,
#    'adults': 514},
#   'injuried': {'total': 1459,
#    'men': 15,
#    'women': 117,
#    'girls': 22,
#    'boys': 16,
#    'children': 60,
#    'adults': 1088}},
#  {'articlesCount': 25,
#   'tags': [{'title': 'accord', 'count': 9},
#    {'title': 'ukraine', 'count': 7},
#    {'title': 'march', 'count': 7},
#    {'title': 'russian', 'count': 7},
#    {'title': 'ukrainian', 'count': 5},
#    {'title': 'russia', 'count': 5},
#    {'title': 'attack', 'count': 5},
#    {'title': 'oblast', 'count': 5},
#    {'title': 'report', 'count': 4},
#    {'title': 'add', 'count': 3}],
#   'date': datetime.datetime(2022, 3, 20, 0, 0),
#   'deathCounts': 4}]
